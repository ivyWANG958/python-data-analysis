# %%
import pandas as pd

# %%
df = pd.read_csv('top20-35.csv')

# %%
df = df[(df.legend != 'Total Score') & (df.legend != 'Status') ]
df.head()
# Out:
#    Year      legend Germany Saint Vincent and the Grenadines Jamaica Barbados  \
# 0  2001      ALegal       2                                2       3        1
# 1  2001  BPolitical       8                                7       8        4
# 2  2001   CEconomic       5                                7       6       11
# 5  2002      ALegal       2                                2       3        1
# 6  2002  BPolitical       6                                8      11        4
#
#   Bahamas Canada Costa Rica United States Australia Malta  \
# 0       3      1          7             3         0     0
# 1       2      6          4             6         3     5
# 2       3      9          6             7         7     8
# 5       3      2          4             5         3     2
# 6       3      7          5             6         5     4
#
#   Saint Kitts and Nevis Micronesia Czech Republic United Kingdom Lithuania
# 0                     4          2             10              4         4
# 1                     6          2              6              7         7
# 2                     8         16              9              7         8
# 5                     4          2              9              6         7
# 6                     7          3              5              5         5

# %%
df_copy = df.copy()

# %%
# df_num = df.apply(pd.to_numeric)
df_num = df[['Germany',
 'Saint Vincent and the Grenadines',
 'Jamaica',
 'Barbados',
 'Bahamas',
 'Canada',
 'Costa Rica',
 'United States',
 'Australia',
 'Malta',
 'Saint Kitts and Nevis',
 'Micronesia',
 'Czech Republic',
 'United Kingdom',
 'Lithuania']].apply(pd.to_numeric)

#df[['Venezuela','Chad']].apply(pd.to_numeric)

# %%
df = df[['Year','legend']].join(df_num)

# %%
country = ['Germany',
 'Saint Vincent and the Grenadines',
 'Jamaica',
 'Barbados',
 'Bahamas',
 'Canada',
 'Costa Rica',
 'United States',
 'Australia',
 'Malta',
 'Saint Kitts and Nevis',
 'Micronesia',
 'Czech Republic',
 'United Kingdom',
 'Lithuania']

# %%
df_A = df[(df.legend == 'ALegal')]
df_B = df[(df.legend == 'BPolitical')]
df_C = df[(df.legend == 'CEconomic')]

# %%
df_A_score = df_A.drop(['Year','legend'], axis = 1).sum(axis = 0, skipna = True)
bottom_a = df_A_score.sum(axis = 0) / 15/ 30 # scale 0-30
bottom_a
# Out:
# 2.2288888888888887

# %%
df_B_score = df_B.drop(['Year','legend'], axis = 1).sum(axis = 0, skipna = True)
bottom_b = df_B_score.sum(axis = 0) / 15/ 40 # scale 0-40
bottom_b
# Out:
# 3.066666666666667

# %%
df_C_score = df_C.drop(['Year','legend'], axis = 1).sum(axis = 0, skipna = True)
bottom_c = df_C_score.sum(axis = 0) / 15/ 30 # scale 0-30
bottom_c
# Out:
# 3.6666666666666665

# %%
# situtaion: A > B > C

# %%
df_A
# Out:
#     Year  legend  Germany  Saint Vincent and the Grenadines  Jamaica  \
# 0   2001  ALegal        2                                 2        3
# 5   2002  ALegal        2                                 2        3
# 10  2003  ALegal        5                                 1        4
# 15  2004  ALegal        5                                 2        4
# 20  2005  ALegal        5                                 3        3
# 25  2006  ALegal        6                                 4        3
# 30  2007  ALegal        6                                 4        3
# 35  2008  ALegal        6                                 4        3
# 40  2009  ALegal        6                                 4        3
# 45  2010  ALegal        6                                 4        3
# 50  2011  ALegal        6                                 4        3
# 55  2012  ALegal        6                                 4        4
# 60  2013  ALegal        6                                 4        3
# 65  2014  ALegal        6                                 4        3
# 70  2015  ALegal        6                                 4        3
# 75  2016  ALegal        6                                 5        3
#
#     Barbados  Bahamas  Canada  Costa Rica  United States  Australia  Malta  \
# 0          1        3       1           7              3          0      0
# 5          1        3       2           4              5          3      2
# 10         4        4       2           7              3          3      2
# 15         3        2       3           5              5          4      2
# 20         3        2       4           5              6          5      2
# 25         3        2       3           7              6          6      2
# 30         3        3       4           6              5          6      3
# 35         3        3       5           6              5          6      4
# 40         3        3       5           6              5          6      4
# 45         3        3       5           5              4          5      4
# 50         3        3       5           5              3          4      4
# 55         3        3       5           5              3          4      4
# 60         3        4       5           5              6          5      5
# 65         3        5       5           4              6          5      5
# 70         3        5       5           4              6          6      5
# 75         3        5       5           4              6          6      5
#
#     Saint Kitts and Nevis  Micronesia  Czech Republic  United Kingdom  \
# 0                       4           2              10               4
# 5                       4           2               9               6
# 10                      2           1               6               4
# 15                      6           1               6               5
# 20                      4           1               5               5
# 25                      4           1               4               5
# 30                      4           2               4               6
# 35                      4           2               4               6
# 40                      4           2               4               6
# 45                      4           2               4               6
# 50                      4           2               4               7
# 55                      4           2               4               7
# 60                      4           2               4               8
# 65                      4           2               4               9
# 70                      4           2               4               9
# 75                      4           2               4               9
#
#     Lithuania
# 0           4
# 5           7
# 10          5
# 15          5
# 20          5
# 25          5
# 30          5
# 35          5
# 40          5
# 45          5
# 50          5
# 55          6
# 60          6
# 65          7
# 70          6
# 75          6

# %%
df_B
# Out:
#     Year      legend  Germany  Saint Vincent and the Grenadines  Jamaica  \
# 1   2001  BPolitical        8                                 7        8
# 6   2002  BPolitical        6                                 8       11
# 11  2003  BPolitical        6                                 5        7
# 16  2004  BPolitical        6                                 5        5
# 21  2005  BPolitical        6                                 6        7
# 26  2006  BPolitical        6                                 7        6
# 31  2007  BPolitical        6                                 7        6
# 36  2008  BPolitical        6                                 7        6
# 41  2009  BPolitical        7                                 7        7
# 46  2010  BPolitical        7                                 7        9
# 51  2011  BPolitical        7                                 7        9
# 56  2012  BPolitical        7                                 7        8
# 61  2013  BPolitical        7                                 7        8
# 66  2014  BPolitical        8                                 7        8
# 71  2015  BPolitical       10                                 7        8
# 76  2016  BPolitical       10                                 9        9
#
#     Barbados  Bahamas  Canada  Costa Rica  United States  Australia  Malta  \
# 1          4        2       6           4              6          3      5
# 6          4        3       7           5              6          5      4
# 11         6        5       7           7              6          4      5
# 16         6        6       8           7              7          7      7
# 21         8        8       8           6              6          8      7
# 26         8        9       8           7              6          9      6
# 31        10       10       8           7              8          8      8
# 36        10       10       8           7              8          9      9
# 41        10       10       8           7              8          9      9
# 46        10       10       8           7              8          9      9
# 51        10       10       8           8             10         10      9
# 56         9        9       9           7             10         10      9
# 61         9        9       8           7             10         10      9
# 66         9        9       7           7             11         10      9
# 71         9       10       7           7             10         10      9
# 76        10       11       7           6             12          9      9
#
#     Saint Kitts and Nevis  Micronesia  Czech Republic  United Kingdom  \
# 1                       6           2               6               7
# 6                       7           3               5               5
# 11                      9           7              10               8
# 16                      8           7               9               7
# 21                      9           8               8               7
# 26                      8           8               7               8
# 31                      8           8               7               7
# 36                      8           8               7               8
# 41                      9           8               7               8
# 46                      9           8               8               8
# 51                      9           8               8               9
# 56                      9           8               8               9
# 61                      9           8               8              10
# 66                      9           8               8               9
# 71                      9           8               8               9
# 76                     10           8               8               9
#
#     Lithuania
# 1           7
# 6           5
# 11          7
# 16          7
# 21          7
# 26          7
# 31          7
# 36          7
# 41          9
# 46          9
# 51          9
# 56          8
# 61          8
# 66          8
# 71          7
# 76          6

# %%
df_A.describe().round()
# Out:
#          Year  Germany  Saint Vincent and the Grenadines  Jamaica  Barbados  \
# count    16.0     16.0                              16.0     16.0      16.0
# mean   2008.0      5.0                               3.0      3.0       3.0
# std       5.0      1.0                               1.0      0.0       1.0
# min    2001.0      2.0                               1.0      3.0       1.0
# 25%    2005.0      5.0                               3.0      3.0       3.0
# 50%    2008.0      6.0                               4.0      3.0       3.0
# 75%    2012.0      6.0                               4.0      3.0       3.0
# max    2016.0      6.0                               5.0      4.0       4.0
#
#        Bahamas  Canada  Costa Rica  United States  Australia  Malta  \
# count     16.0    16.0        16.0           16.0       16.0   16.0
# mean       3.0     4.0         5.0            5.0        5.0    3.0
# std        1.0     1.0         1.0            1.0        2.0    1.0
# min        2.0     1.0         4.0            3.0        0.0    0.0
# 25%        3.0     3.0         5.0            4.0        4.0    2.0
# 50%        3.0     5.0         5.0            5.0        5.0    4.0
# 75%        4.0     5.0         6.0            6.0        6.0    4.0
# max        5.0     5.0         7.0            6.0        6.0    5.0
#
#        Saint Kitts and Nevis  Micronesia  Czech Republic  United Kingdom  \
# count                   16.0        16.0            16.0            16.0
# mean                     4.0         2.0             5.0             6.0
# std                      1.0         0.0             2.0             2.0
# min                      2.0         1.0             4.0             4.0
# 25%                      4.0         2.0             4.0             5.0
# 50%                      4.0         2.0             4.0             6.0
# 75%                      4.0         2.0             5.0             7.0
# max                      6.0         2.0            10.0             9.0
#
#        Lithuania
# count       16.0
# mean         5.0
# std          1.0
# min          4.0
# 25%          5.0
# 50%          5.0
# 75%          6.0
# max          7.0

# %%
df_B.describe().round()
# Out:
#          Year  Germany  Saint Vincent and the Grenadines  Jamaica  Barbados  \
# count    16.0     16.0                              16.0     16.0      16.0
# mean   2008.0      7.0                               7.0      8.0       8.0
# std       5.0      1.0                               1.0      2.0       2.0
# min    2001.0      6.0                               5.0      5.0       4.0
# 25%    2005.0      6.0                               7.0      7.0       8.0
# 50%    2008.0      7.0                               7.0      8.0       9.0
# 75%    2012.0      7.0                               7.0      8.0      10.0
# max    2016.0     10.0                               9.0     11.0      10.0
#
#        Bahamas  Canada  Costa Rica  United States  Australia  Malta  \
# count     16.0    16.0        16.0           16.0       16.0   16.0
# mean       8.0     8.0         7.0            8.0        8.0    8.0
# std        3.0     1.0         1.0            2.0        2.0    2.0
# min        2.0     6.0         4.0            6.0        3.0    4.0
# 25%        8.0     7.0         7.0            6.0        8.0    7.0
# 50%        9.0     8.0         7.0            8.0        9.0    9.0
# 75%       10.0     8.0         7.0           10.0       10.0    9.0
# max       11.0     9.0         8.0           12.0       10.0    9.0
#
#        Saint Kitts and Nevis  Micronesia  Czech Republic  United Kingdom  \
# count                   16.0        16.0            16.0            16.0
# mean                     8.0         7.0             8.0             8.0
# std                      1.0         2.0             1.0             1.0
# min                      6.0         2.0             5.0             5.0
# 25%                      8.0         8.0             7.0             7.0
# 50%                      9.0         8.0             8.0             8.0
# 75%                      9.0         8.0             8.0             9.0
# max                     10.0         8.0            10.0            10.0
#
#        Lithuania
# count       16.0
# mean         7.0
# std          1.0
# min          5.0
# 25%          7.0
# 50%          7.0
# 75%          8.0
# max          9.0

# %%
df_C.describe().round()
# Out:
#          Year  Germany  Saint Vincent and the Grenadines  Jamaica  Barbados  \
# count    16.0     16.0                              16.0     16.0      16.0
# mean   2008.0      4.0                               7.0      6.0       7.0
# std       5.0      1.0                               1.0      0.0       1.0
# min    2001.0      4.0                               6.0      6.0       6.0
# 25%    2005.0      4.0                               6.0      6.0       6.0
# 50%    2008.0      4.0                               6.0      6.0       6.0
# 75%    2012.0      5.0                               7.0      6.0       6.0
# max    2016.0      7.0                               9.0      7.0      11.0
#
#        Bahamas  Canada  Costa Rica  United States  Australia  Malta  \
# count     16.0    16.0        16.0           16.0       16.0   16.0
# mean       6.0     6.0         6.0            5.0        7.0    9.0
# std        1.0     1.0         1.0            1.0        0.0    1.0
# min        3.0     6.0         5.0            4.0        6.0    7.0
# 25%        6.0     6.0         6.0            5.0        7.0    9.0
# 50%        7.0     6.0         6.0            5.0        7.0    9.0
# 75%        7.0     6.0         6.0            5.0        7.0    9.0
# max        7.0     9.0         7.0            7.0        7.0    9.0
#
#        Saint Kitts and Nevis  Micronesia  Czech Republic  United Kingdom  \
# count                   16.0        16.0            16.0            16.0
# mean                     8.0        11.0             8.0             6.0
# std                      1.0         1.0             1.0             1.0
# min                      7.0        10.0             7.0             5.0
# 25%                      7.0        11.0             7.0             5.0
# 50%                      7.0        11.0             7.0             6.0
# 75%                      8.0        11.0             9.0             7.0
# max                     10.0        16.0             9.0             7.0
#
#        Lithuania
# count       16.0
# mean         8.0
# std          2.0
# min          6.0
# 25%          6.0
# 50%          8.0
# 75%          9.0
# max         10.0

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(16,12))

for i in country:
    plt.plot(df_A[i], label= i )
    plt.legend(loc=3)

plt.title('A-Legal score by_year top')
plt.xlabel('year')
plt.ylabel('score')
# Out:
# Text(0, 0.5, 'score')

# %%
plt.figure(figsize=(16,12))
for i in country:
    plt.plot(df_B[i], label= i )
    plt.legend()

    #B-Political	C-Economic	
plt.title('B-Political score by_year top')
plt.xlabel('year')
plt.ylabel('score')
# Out:
# Text(0, 0.5, 'score')

# %%
plt.figure(figsize=(16, 12))
for i in country:
    plt.plot(df_C[i], label= i )
    plt.legend()

    #B-Political	C-Economic	
plt.title('C-Economic score by_year top')
plt.xlabel('year')
plt.ylabel('score')
# Out:
# Text(0, 0.5, 'score')

# %%
df_A.drop(['Year','legend'], axis = 1).plot.box(figsize=(16,12));
plt.title('A-Legal boxplot by_country top')
plt.xlabel('country')
plt.ylabel('score')
# Out:
# Text(0, 0.5, 'score')

# %%
df_B.drop(['Year','legend'], axis = 1).plot.box(figsize=(16,12));
plt.title('B-Political boxplot by_country top') #B-Political	C-Economic	
plt.xlabel('country')
plt.ylabel('score')
# Out:
# Text(0, 0.5, 'score')

# %%
df_C.drop(['Year','legend'], axis = 1).plot.box(figsize=(16,12));
plt.title('C-Economic boxplot by_country top') #B-Political	C-Economic	
plt.xlabel('country')
plt.ylabel('score')
# Out:
# Text(0, 0.5, 'score')

# %%
Year = ['2001','2002','2003','2004','2005', '2006', '2007','2008','2009','2010','2011','2012','2013','2014','2015','2016']

# %%
df_C.drop(['Year','legend'], axis = 1).transpose()
# Out:
#                                   2   7   12  17  22  27  32  37  42  47  52  \
# Germany                            5   7   5   5   5   4   4   4   4   4   4
# Saint Vincent and the Grenadines   7   7   8   9   7   6   6   6   6   6   6
# Jamaica                            6   6   6   6   7   6   6   6   6   6   6
# Barbados                          11   9   7   8   6   6   6   6   6   6   6
# Bahamas                            3   5   5   6   6   6   7   7   7   7   7
# Canada                             9   8   6   6   6   6   6   6   6   6   6
# Costa Rica                         6   5   5   7   7   6   6   6   6   6   6
# United States                      7   6   4   5   4   4   4   5   5   5   5
# Australia                          7   6   7   7   6   6   7   7   7   7   7
# Malta                              8   7   8   9   9   9   9   9   9   9   9
# Saint Kitts and Nevis              8   7  10   9   8   8   7   7   7   7   7
# Micronesia                        16  12  11  10  11  11  11  11  11  11  11
# Czech Republic                     9   9   7   7   7   7   7   7   7   7   7
# United Kingdom                     7   7   7   6   7   6   5   5   5   5   5
# Lithuania                          8   6   6   6   6   6   6   6   7   8   9
#
#                                   57  62  67  72  77
# Germany                            4   4   4   4   4
# Saint Vincent and the Grenadines   6   6   6   6   7
# Jamaica                            6   6   6   7   7
# Barbados                           6   6   6   6   6
# Bahamas                            7   7   7   7   7
# Canada                             6   6   6   6   6
# Costa Rica                         6   6   6   6   6
# United States                      5   5   5   5   5
# Australia                          7   7   7   7   7
# Malta                              9   9   9   9   9
# Saint Kitts and Nevis              7   7   7   7   7
# Micronesia                        11  11  11  11  11
# Czech Republic                     7   8   9   9   9
# United Kingdom                     5   5   6   7   7
# Lithuania                         10  10  10  10   9

# %%
df_AT = df_A.reset_index()
df_AT.drop(['Year','legend','index'], axis = 1).transpose().plot.box(figsize=(16,12));


plt.title('A-Legal boxplot by_year top') #A-Legal	B-Political 	C-Economic
plt.xlabel('year')
plt.ylabel('score')
# Out:
# Text(0, 0.5, 'score')

# %%
df_BT = df_B.reset_index()
df_BT.drop(['Year','legend','index'], axis = 1).transpose().plot.box(figsize=(16,12));


plt.title('B-Political boxplot by_year top') #B-Political	C-Economic	
plt.xlabel('year')
plt.ylabel('score')
# Out:
# Text(0, 0.5, 'score')

# %%
df_CT = df_C.reset_index()
df_CT.drop(['Year','legend','index'], axis = 1).transpose().plot.box(figsize=(16,12));


plt.title('C-Economic boxplot by_year top') 
plt.xlabel('year')
plt.ylabel('score')
# Out:
# Text(0, 0.5, 'score')
