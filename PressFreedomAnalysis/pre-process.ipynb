# %%
import pandas as pd

# %%
df = pd.read_csv('2001-2017.csv')
df.head()
# Out:
#    Year       legend Afghanistan Albania Algeria Andorra Angola  \
# 0  2001       ALegal         NaN      24      21     NaN     21
# 1  2001   BPolitical         NaN      12      26     NaN     33
# 2  2001    CEconomic         NaN      12      15     NaN     25
# 3  2001  Total Score         NaN      48      62     NaN     79
# 4  2001       Status         NaN      PF      NF     NaN     NF
#
#   Antigua and Barbuda Argentina Armenia   ...    Vanuatu Venezuela Vietnam  \
# 0                  12        10      21   ...          4        19      30
# 1                  16        21      26   ...          4        15      30
# 2                  16         6      13   ...         16        10      22
# 3                  44        37      60   ...         24        44      82
# 4                  PF        PF      PF   ...          F        PF      NF
#
#   West Bank and Gaza Strip Yemen Yemen, North Yemen, South Yugoslavia Zambia  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Columns: 212 entries, Year to Zimbabwe
# dtypes: float64(9), int64(1), object(202)
# memory usage: 132.6+ KB

# %%
df_copy = df.copy()

# %%
df_total = df[df.legend == 'Total Score']

# %%
df_total.head()
# Out:
#     Year       legend Afghanistan Albania Algeria Andorra Angola  \
# 3   2001  Total Score         NaN      48      62     NaN     79
# 8   2002  Total Score          74      50      62       8     72
# 13  2003  Total Score          72      49      63      13     66
# 18  2004  Total Score          68      51      64      14     66
# 23  2005  Total Score          69      50      61      14     65
#
#    Antigua and Barbuda Argentina Armenia   ...    Vanuatu Venezuela Vietnam  \
# 3                   44        37      60   ...         24        44      82
# 8                   45        39      65   ...         21        68      82
# 13                  43        35      64   ...         23        68      82
# 18                  40        41      64   ...         24        72      82
# 23                  38        45      64   ...         25        72      79
#
#    West Bank and Gaza Strip Yemen Yemen, North Yemen, South Yugoslavia Zambia  \
# ...

# %%
df_total.info()
df_total_copy = df_total.copy()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16 entries, 3 to 78
# Columns: 212 entries, Year to Zimbabwe
# dtypes: float64(9), int64(1), object(202)
# memory usage: 26.6+ KB

# %%
df_total = df_total.drop(df_total.columns[0], axis = 1)
df_total = df_total.drop(df_total.columns[0], axis = 1)

df_total.to_csv('total2001-2017.csv')

# %%
df_total = pd.read_csv('total2001-2017.csv')
df_total.head()
# Out:
#    Afghanistan  Albania  Algeria  Andorra  Angola  Antigua and Barbuda  \
# 0          NaN       48       62      NaN      79                   44
# 1         74.0       50       62      8.0      72                   45
# 2         72.0       49       63     13.0      66                   43
# 3         68.0       51       64     14.0      66                   40
# 4         69.0       50       61     14.0      65                   38
#
#    Argentina  Armenia  Australia  Austria    ...     United Kingdom  \
# 0         37       60         10       24    ...                 18
# 1         39       65         14       23    ...                 18
# 2         35       64         14       23    ...                 19
# 3         41       64         18       21    ...                 18
# 4         45       64         19       21    ...                 19
#
#    United States  Uruguay  Uzbekistan  Vanuatu  Venezuela  Vietnam  Yemen  \
# ...

# %%
columnsNamesArr = df_total.columns.values 
    # convert ndarray to list
listOfColumnNames = list(columnsNamesArr)

# %%
for i in listOfColumnNames:
    df_total[i].fillna((df_total[i].mean()), inplace=True)

# %%
df_sort = df_total.sum(axis = 0, skipna = True).round()

# %%
len(df_sort) # ignore first and last 10% aka. 20 items, and pick remaining first and last 10% aka. 15 items
# Out:
# 196

# %%
df_top = df_sort.sort_values().head(35)
df_bottom = df_sort.sort_values().tail(35)

# %%
df_top.to_csv('top35.csv')
df_bottom.to_csv('bottom35.csv')

# %%
df_top = pd.read_csv('top35.csv')
topC = df_top['country'].values.tolist()
df_bottom = pd.read_csv('bottom35.csv')
bottomC = df_bottom['country'].values.tolist()

# %%
topC[20:]
# Out:
# ['Germany',
#  'Saint Vincent and the Grenadines',
#  'Jamaica',
#  'Barbados',
#  'Bahamas',
#  'Canada',
#  'Costa Rica',
#  'United States',
#  'Australia',
#  'Malta',
#  'Saint Kitts and Nevis',
#  'Micronesia',
#  'Czech Republic',
#  'United Kingdom',
#  'Lithuania']

# %%
bottomC[:15]
# Out:
# ['United Arab Emirates',
#  'Venezuela',
#  'Chad',
#  'Burundi',
#  'Brunei',
#  'Ethiopia',
#  'Russia',
#  'Bahrain',
#  'The Gambia',
#  'Swaziland',
#  'Yemen',
#  'Tajikistan',
#  'Kazakhstan',
#  'Azerbaijan',
#  'Congo (Kinshasa)']
