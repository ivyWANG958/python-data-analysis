# %%
import pandas as pd

# %%
df = pd.read_csv('bottom20-35.csv')

# %%
df = df[(df.legend != 'Total Score') & (df.legend != 'Status') ]
df.head()
# Out:
#    Year      legend United Arab Emirates Venezuela Chad Burundi Brunei  \
# 0  2001      ALegal                   26        19   26      25     26
# 1  2001  BPolitical                   23        15   22      28     29
# 2  2001   CEconomic                   25        10   26      24     23
# 5  2002      ALegal                   24        23   20      21     28
# 6  2002  BPolitical                   27        29   26      32     26
#
#   Ethiopia Russia Bahrain The Gambia Swaziland Yemen Tajikistan Kazakhstan  \
# 0       23     13      26         18        26    27         29         24
# 1       20     30      24         29        26    23         27         22
# 2       18     17      25         18        25    15         24         23
# 5       23     14      20         20        23    27         26         24
# 6       23     30      25         27        26    24         26         27
#
#   Azerbaijan Congo (Kinshasa)
# 0         26               26
# 1         28               34
# 2         23               26
# 5         22               25
# 6         28               35

# %%
df_copy = df.copy()

# %%
# df_num = df.apply(pd.to_numeric)
df_num = df[['United Arab Emirates','Venezuela','Chad','Burundi','Brunei','Ethiopia','Russia','Bahrain','The Gambia','Swaziland','Yemen','Tajikistan','Kazakhstan','Azerbaijan','Congo (Kinshasa)']].apply(pd.to_numeric)

#df[['Venezuela','Chad']].apply(pd.to_numeric)

# %%
df = df[['Year','legend']].join(df_num)

# %%
df['Chad'].sum()
# Out:
# 1185

# %%
country = ['United Arab Emirates',
 'Venezuela',
 'Chad',
 'Burundi',
 'Brunei',
 'Ethiopia',
 'Russia',
 'Bahrain',
 'The Gambia',
 'Swaziland',
 'Yemen',
 'Tajikistan',
 'Kazakhstan',
 'Azerbaijan',
 'Congo (Kinshasa)']

# %%
df_A = df[(df.legend == 'ALegal')]
df_B = df[(df.legend == 'BPolitical')]
df_C = df[(df.legend == 'CEconomic')]

# %%
df_A_score = df_A.drop(['Year','legend'], axis = 1).sum(axis = 0, skipna = True)
bottom_a = df_A_score.sum(axis = 0) / 15/ 30 # scale 0-30
bottom_a
# Out:
# 13.235555555555555

# %%
df_B_score = df_B.drop(['Year','legend'], axis = 1).sum(axis = 0, skipna = True)
bottom_b = df_B_score.sum(axis = 0) / 15/ 40 # scale 0-40
bottom_b
# Out:
# 11.813333333333334

# %%
df_C_score = df_C.drop(['Year','legend'], axis = 1).sum(axis = 0, skipna = True)
bottom_c = df_C_score.sum(axis = 0) / 15/ 30 # scale 0-30
bottom_c
# Out:
# 11.77111111111111

# %%
# situtaion: C > B > A

# %%
pd.options.display.max_columns = 100

# %%
df_A
# Out:
#     Year  legend  United Arab Emirates  Venezuela  Chad  Burundi  Brunei  \
# 0   2001  ALegal                    26         19    26       25      26
# 5   2002  ALegal                    24         23    20       21      28
# 10  2003  ALegal                    27         22    24       21      27
# 15  2004  ALegal                    26         24    23       21      27
# 20  2005  ALegal                    23         25    23       21      28
# 25  2006  ALegal                    23         26    23       22      28
# 30  2007  ALegal                    23         26    23       21      28
# 35  2008  ALegal                    23         26    24       21      28
# 40  2009  ALegal                    24         26    24       21      28
# 45  2010  ALegal                    24         27    23       22      28
# 50  2011  ALegal                    24         27    23       23      28
# 55  2012  ALegal                    24         27    23       23      28
# 60  2013  ALegal                    25         26    22       24      28
# 65  2014  ALegal                    25         26    22       24      28
# 70  2015  ALegal                    25         26    22       25      28
# 75  2016  ALegal                    25         26    22       25      28
#
#     Ethiopia  Russia  Bahrain  The Gambia  Swaziland  Yemen  Tajikistan  \
# 0         23      13       26          18         26     27          29
# 5         23      14       20          20         23     27          26
# 10        24      14       22          20         23     26          24
# 15        25      14       23          22         25     28          24
# 20        27      16       24          24         25     28          24
# 25        27      18       23          24         25     28          24
# 30        27      21       24          25         25     26          25
# 35        25      23       24          25         25     26          25
# 40        27      24       24          26         24     26          25
# 45        27      24       25          26         24     27          25
# 50        28      24       28          26         24     27          25
# 55        28      25       28          28         24     25          25
# 60        27      25       28          28         25     24          25
# 65        28      25       28          27         25     24          25
# 70        28      25       28          29         25     26          26
# 75        29      25       28          29         26     26          28
#
#     Kazakhstan  Azerbaijan  Congo (Kinshasa)
# 0           24          26                26
# 5           24          22                25
# 10          25          24                25
# 15          25          23                25
# 20          25          23                25
# 25          26          24                24
# 30          26          25                25
# 35          26          25                25
# 40          26          25                25
# 45          28          26                25
# 50          28          26                16
# 55          29          27                26
# 60          29          28                24
# 65          29          29                17
# 70          28          29                24
# 75          28          29                25

# %%
df_B
# Out:
#     Year      legend  United Arab Emirates  Venezuela  Chad  Burundi  Brunei  \
# 1   2001  BPolitical                    23         15    22       28      29
# 6   2002  BPolitical                    27         29    26       32      26
# 11  2003  BPolitical                    25         29    29       30      25
# 16  2004  BPolitical                    24         30    29       29      26
# 21  2005  BPolitical                    22         30    29       29      27
# 26  2006  BPolitical                    23         30    30       31      26
# 31  2007  BPolitical                    23         29    30       29      25
# 36  2008  BPolitical                    23         28    31       30      25
# 41  2009  BPolitical                    24         30    32       30      25
# 46  2010  BPolitical                    24         29    31       30      25
# 51  2011  BPolitical                    25         29    31       28      25
# 56  2012  BPolitical                    27         29    31       28      25
# 61  2013  BPolitical                    28         30    31       29      25
# 66  2014  BPolitical                    28         31    30       29      25
# 71  2015  BPolitical                    30         30    30       33      25
# 76  2016  BPolitical                    30         31    30       37      25
#
#     Ethiopia  Russia  Bahrain  The Gambia  Swaziland  Yemen  Tajikistan  \
# 1         20      30       24          29         26     23          27
# 6         23      30       25          27         26     24          26
# 11        23      30       25          25         28     22          27
# 16        23      31       26          31         28     28          27
# 21        28      32       26          30         27     33          28
# 26        30      33       26          33         26     31          28
# 31        30      33       27          34         26     31          28
# 36        33      33       27          34         26     31          28
# 41        33      33       27          35         27     32          28
# 46        33      33       27          35         27     33          28
# 51        35      32       35          35         27     33          29
# 56        35      32       37          35         28     31          29
# 61        35      32       37          35         28     29          30
# 66        36      34       37          34         28     31          32
# 71        36      34       37          36         30     34          32
# 76        38      34       37          35         30     36          33
#
#     Kazakhstan  Azerbaijan  Congo (Kinshasa)
# 1           22          28                34
# 6           27          28                35
# 11          27          26                31
# 16          28          27                31
# 21          28          27                31
# 26          28          29                32
# 31          30          30                32
# 36          30          31                32
# 41          30          32                32
# 46          29          31                32
# 51          30          32                22
# 56          32          33                33
# 61          33          34                31
# 66          33          36                25
# 71          33          38                30
# 76          34          39                32

# %%
df_A.describe().round()
# Out:
#          Year  United Arab Emirates  Venezuela  Chad  Burundi  Brunei  \
# count    16.0                  16.0       16.0  16.0     16.0    16.0
# mean   2008.0                  24.0       25.0  23.0     22.0    28.0
# std       5.0                   1.0        2.0   1.0      2.0     1.0
# min    2001.0                  23.0       19.0  20.0     21.0    26.0
# 25%    2005.0                  24.0       25.0  22.0     21.0    28.0
# 50%    2008.0                  24.0       26.0  23.0     22.0    28.0
# 75%    2012.0                  25.0       26.0  23.0     24.0    28.0
# max    2016.0                  27.0       27.0  26.0     25.0    28.0
#
#        Ethiopia  Russia  Bahrain  The Gambia  Swaziland  Yemen  Tajikistan  \
# count      16.0    16.0     16.0        16.0       16.0   16.0        16.0
# mean       26.0    21.0     25.0        25.0       25.0   26.0        25.0
# std         2.0     5.0      3.0         3.0        1.0    1.0         1.0
# min        23.0    13.0     20.0        18.0       23.0   24.0        24.0
# 25%        25.0    16.0     24.0        24.0       24.0   26.0        25.0
# 50%        27.0    24.0     24.0        26.0       25.0   26.0        25.0
# 75%        28.0    25.0     28.0        27.0       25.0   27.0        25.0
# max        29.0    25.0     28.0        29.0       26.0   28.0        29.0
#
#        Kazakhstan  Azerbaijan  Congo (Kinshasa)
# count        16.0        16.0              16.0
# mean         27.0        26.0              24.0
# std           2.0         2.0               3.0
# min          24.0        22.0              16.0
# 25%          25.0        24.0              24.0
# 50%          26.0        26.0              25.0
# 75%          28.0        27.0              25.0
# max          29.0        29.0              26.0

# %%
df_B.describe().round()
# Out:
#          Year  United Arab Emirates  Venezuela  Chad  Burundi  Brunei  \
# count    16.0                  16.0       16.0  16.0     16.0    16.0
# mean   2008.0                  25.0       29.0  30.0     30.0    26.0
# std       5.0                   3.0        4.0   2.0      2.0     1.0
# min    2001.0                  22.0       15.0  22.0     28.0    25.0
# 25%    2005.0                  23.0       29.0  29.0     29.0    25.0
# 50%    2008.0                  24.0       30.0  30.0     30.0    25.0
# 75%    2012.0                  27.0       30.0  31.0     30.0    26.0
# max    2016.0                  30.0       31.0  32.0     37.0    29.0
#
#        Ethiopia  Russia  Bahrain  The Gambia  Swaziland  Yemen  Tajikistan  \
# count      16.0    16.0     16.0        16.0       16.0   16.0        16.0
# mean       31.0    32.0     30.0        33.0       27.0   30.0        29.0
# std         6.0     1.0      5.0         3.0        1.0    4.0         2.0
# min        20.0    30.0     24.0        25.0       26.0   22.0        26.0
# 25%        27.0    32.0     26.0        31.0       26.0   29.0        28.0
# 50%        33.0    32.0     27.0        34.0       27.0   31.0        28.0
# 75%        35.0    33.0     37.0        35.0       28.0   33.0        29.0
# max        38.0    34.0     37.0        36.0       30.0   36.0        33.0
#
#        Kazakhstan  Azerbaijan  Congo (Kinshasa)
# count        16.0        16.0              16.0
# mean         30.0        31.0              31.0
# std           3.0         4.0               3.0
# min          22.0        26.0              22.0
# 25%          28.0        28.0              31.0
# 50%          30.0        31.0              32.0
# 75%          32.0        33.0              32.0
# max          34.0        39.0              35.0

# %%
df_C.describe().round()
# Out:
#          Year  United Arab Emirates  Venezuela  Chad  Burundi  Brunei  \
# count    16.0                  16.0       16.0  16.0     16.0    16.0
# mean   2008.0                  23.0       19.0  22.0     23.0    22.0
# std       5.0                   1.0        4.0   1.0      1.0     0.0
# min    2001.0                  20.0       10.0  21.0     21.0    22.0
# 25%    2005.0                  23.0       18.0  21.0     22.0    22.0
# 50%    2008.0                  23.0       19.0  21.0     23.0    22.0
# 75%    2012.0                  23.0       20.0  22.0     24.0    22.0
# max    2016.0                  25.0       24.0  26.0     24.0    23.0
#
#        Ethiopia  Russia  Bahrain  The Gambia  Swaziland  Yemen  Tajikistan  \
# count      16.0    16.0     16.0        16.0       16.0   16.0        16.0
# mean       19.0    23.0     22.0        20.0       25.0   21.0        24.0
# std         1.0     2.0      1.0         1.0        1.0    2.0         1.0
# min        18.0    17.0     20.0        18.0       25.0   15.0        22.0
# 25%        18.0    24.0     21.0        19.0       25.0   20.0        24.0
# 50%        19.0    24.0     22.0        20.0       25.0   22.0        25.0
# 75%        19.0    24.0     22.0        20.0       26.0   23.0        25.0
# max        20.0    24.0     25.0        23.0       27.0   23.0        26.0
#
#        Kazakhstan  Azerbaijan  Congo (Kinshasa)
# count        16.0        16.0              16.0
# mean         22.0        22.0              23.0
# std           1.0         0.0               3.0
# min          22.0        21.0              17.0
# 25%          22.0        22.0              24.0
# 50%          22.0        22.0              24.0
# 75%          23.0        22.0              24.0
# max          23.0        23.0              26.0

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(16,12))

for i in country:
    plt.plot(df_A[i], label= i )
    plt.legend()

plt.title('A-Legal score by year_bottom')
plt.xlabel('year')
plt.ylabel('score')
# Out:
# Text(0, 0.5, 'score')

# %%
plt.figure(figsize=(16,12))
for i in country:
    plt.plot(df_B[i], label= i )
    plt.legend()

    #B-Political	C-Economic	
plt.title('B-Political score by year_bottom')
plt.xlabel('year')
plt.ylabel('score')
# Out:
# Text(0, 0.5, 'score')

# %%
plt.figure(figsize=(16,12))
for i in country:
    plt.plot(df_C[i], label= i )
    plt.legend()

    #B-Political	C-Economic	
plt.title('C-Economic score by year_bottom')
plt.xlabel('year')
plt.ylabel('score')
# Out:
# Text(0, 0.5, 'score')

# %%
df_A.drop(['Year','legend'], axis = 1).plot.box(figsize=(16,12));
plt.title('A-Legal boxplot by_country bottom')
plt.xlabel('country')
plt.ylabel('score')
# Out:
# Text(0, 0.5, 'score')

# %%
df_B.drop(['Year','legend'], axis = 1).plot.box(figsize=(16,12));
plt.title('B-Political boxplot by_country bottom') #B-Political	C-Economic	
plt.xlabel('country')
plt.ylabel('score')
# Out:
# Text(0, 0.5, 'score')

# %%
df_C.drop(['Year','legend'], axis = 1).plot.box(figsize=(16,12));
plt.title('C-Economic boxplot by_country bottom') #B-Political	C-Economic	
plt.xlabel('country')
plt.ylabel('score')
# Out:
# Text(0, 0.5, 'score')

# %%
Year = ['2001','2002','2003','2004','2005', '2006', '2007','2008','2009','2010','2011','2012','2013','2014','2015','2016']

# %%
df_AT = df_A.reset_index()
df_AT.drop(['Year','legend','index'], axis = 1).transpose().plot.box(figsize=(16,12));


plt.title('A-Legal boxplot by_year bottom') #A-Legal	B-Political 	C-Economic
plt.xlabel('year')
plt.ylabel('score')
# Out:
# Text(0, 0.5, 'score')

# %%
df_BT = df_B.reset_index()
df_BT.drop(['Year','legend','index'], axis = 1).transpose().plot.box(figsize=(16,12));


plt.title('B-Political boxplot by_year bottom') #A-Legal	B-Political 	C-Economic
plt.xlabel('year')
plt.ylabel('score')
# Out:
# Text(0, 0.5, 'score')

# %%
df_CT = df_C.reset_index()
df_CT.drop(['Year','legend','index'], axis = 1).transpose().plot.box(figsize=(16,12));


plt.title('C-Economic boxplot by_year bottom') #A-Legal	B-Political 	C-Economic
plt.xlabel('year')
plt.ylabel('score')
# Out:
# Text(0, 0.5, 'score')
